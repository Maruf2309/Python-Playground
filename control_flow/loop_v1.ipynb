# %% [markdown]
# # Loop

# %%
list = [1, 2, 3 , 7, 8, 11, 14, 15, 16, 20]
list
# Out:
# [1, 2, 3, 7, 8, 11, 14, 15, 16, 20]

# %%
# Find the Even Number
for num in list:
    if num % 2 == 0: # it check whether its divisable by 2
        print(num)
# Out:
# 2
# 8
# 14
# 16
# 20

# %%
# Alternative
[print(num) for num in list if num % 2 == 0]
# Out:
# 2
# 8
# 14
# 16
# 20
# [None, None, None, None, None]
